# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
np.random.seed(0)
dataset = np.random.randint(0, 100, [50, 5])

dataset
# Out:
# array([[44, 47, 64, 67, 67],
#        [ 9, 83, 21, 36, 87],
#        [70, 88, 88, 12, 58],
#        [65, 39, 87, 46, 88],
#        [81, 37, 25, 77, 72],
#        [ 9, 20, 80, 69, 79],
#        [47, 64, 82, 99, 88],
#        [49, 29, 19, 19, 14],
#        [39, 32, 65,  9, 57],
#        [32, 31, 74, 23, 35],
#        [75, 55, 28, 34,  0],
#        [ 0, 36, 53,  5, 38],
#        [17, 79,  4, 42, 58],
#        [31,  1, 65, 41, 57],
#        [35, 11, 46, 82, 91],
#        [ 0, 14, 99, 53, 12],
#        [42, 84, 75, 68,  6],
#        [68, 47,  3, 76, 52],
#        [78, 15, 20, 99, 58],
#        [23, 79, 13, 85, 48],
#        [49, 69, 41, 35, 64],
#        [95, 69, 94,  0, 50],
#        [36, 34, 48, 93,  3],
#        [98, 42, 77, 21, 73],
#        [ 0, 10, 43, 58, 23],
#        [59,  2, 98, 62, 35],
#        [94, 67, 82, 46, 99],
#        [20, 81, 50, 27, 14],
#        [41, 58, 65, 36, 10],
#        [86, 43, 11,  2, 51],
#        [80, 32, 54,  0, 38],
#        [19, 46, 42, 56, 60],
#        [77, 30, 24,  2,  3],
#        [94, 98, 13, 40, 72],
#        [19, 95, 72, 26, 66],
#        [52, 67, 61, 14, 96],
#        [ 4, 67, 11, 86, 77],
#        [75, 56, 16, 24, 29],
#        [21, 25, 80, 60, 61],
#        [83, 33, 32, 70, 85],
#        [31, 13, 71, 56, 24],
#        [79, 41, 18, 40, 54],
#        [79, 11, 38, 93,  1],
#        [95, 44, 88, 24, 67],
#        [82,  3, 76, 35, 86],
#        [61, 69, 87, 43, 32],
#        [11, 84, 10, 54, 37],
#        [28,  2, 27, 83, 89],
#        [23, 53, 51, 46, 20],
#        [53, 29, 67, 35, 39]])

# %%
def see_data(d):
    plt.figure(figsize=(15, 5))

    for i in range(d.shape[1]):
        plt.subplot(1, d.shape[1], i+1)
        plt.plot(np.arange(0, d.shape[0]), d[:, i])
        plt.title(f"Col {i+1}")

see_data(dataset)

# %%
dataset = dataset.astype(np.float16)

dataset = (dataset - dataset.mean(axis=0)) / dataset.std(axis=0)

dataset
# Out:
# array([[-0.1738  ,  0.0642  ,  0.452   ,  0.7515  ,  0.5835  ],
#        [-1.354   ,  1.409   , -1.061   , -0.3677  ,  1.29    ],
#        [ 0.7026  ,  1.596   ,  1.296   , -1.234   ,  0.2659  ],
#        [ 0.534   , -0.2346  ,  1.261   , -0.006767,  1.325   ],
#        [ 1.073   , -0.3093  , -0.9204  ,  1.112   ,  0.7603  ],
#        [-1.354   , -0.9443  ,  1.015   ,  0.823   ,  1.007   ],
#        [-0.0727  ,  0.699   ,  1.085   ,  1.906   ,  1.325   ],
#        [-0.005264, -0.6084  , -1.132   , -0.9814  , -1.287   ],
#        [-0.3423  , -0.496   ,  0.487   , -1.343   ,  0.2306  ],
#        [-0.578   , -0.5337  ,  0.8037  , -0.837   , -0.546   ],
#        [ 0.871   ,  0.363   , -0.815   , -0.44    , -1.781   ],
#        [-1.656   , -0.3467  ,  0.0649  , -1.486   , -0.4402  ],
#        [-1.084   ,  1.26    , -1.659   , -0.1511  ,  0.2659  ],
#        [-0.612   , -1.654   ,  0.487   , -0.1873  ,  0.2306  ],
#        [-0.477   , -1.281   , -0.1814  ,  1.293   ,  1.431   ],
#        [-1.656   , -1.169   ,  1.684   ,  0.246   , -1.358   ],
#        [-0.2412  ,  1.446   ,  0.839   ,  0.7876  , -1.569   ],
#        [ 0.6353  ,  0.0642  , -1.694   ,  1.076   ,  0.05405 ],
#        [ 0.972   , -1.132   , -1.097   ,  1.906   ,  0.2659  ],
#        [-0.8813  ,  1.26    , -1.343   ,  1.401   , -0.08716 ],
#        [-0.005264,  0.886   , -0.3574  , -0.4038  ,  0.4778  ],
#        [ 1.545   ,  0.886   ,  1.508   , -1.667   , -0.01654 ],
#        [-0.4434  , -0.4214  , -0.111   ,  1.689   , -1.676   ],
#        [ 1.646   , -0.1226  ,  0.909   , -0.909   ,  0.7954  ],
#        [-1.656   , -1.318   , -0.2869  ,  0.4265  , -0.9697  ],
#        [ 0.3318  , -1.617   ,  1.648   ,  0.571   , -0.546   ],
#        [ 1.512   ,  0.8115  ,  1.085   , -0.006767,  1.713   ],
#        [-0.9824  ,  1.335   , -0.04068 , -0.6924  , -1.287   ],
#        [-0.275   ,  0.475   ,  0.487   , -0.3677  , -1.429   ],
#        [ 1.242   , -0.0852  , -1.413   , -1.595   ,  0.01875 ],
#        [ 1.039   , -0.496   ,  0.10004 , -1.667   , -0.4402  ],
#        [-1.017   ,  0.02686 , -0.3223  ,  0.3542  ,  0.3364  ],
#        [ 0.9385  , -0.571   , -0.9556  , -1.595   , -1.676   ],
#        [ 1.512   ,  1.97    , -1.343   , -0.2234  ,  0.7603  ],
#        [-1.017   ,  1.857   ,  0.7334  , -0.7285  ,  0.5483  ],
#        [ 0.0958  ,  0.8115  ,  0.3464  , -1.162   ,  1.607   ],
#        [-1.521   ,  0.8115  , -1.413   ,  1.4375  ,  0.9365  ],
#        [ 0.871   ,  0.4004  , -1.237   , -0.801   , -0.758   ],
#        [-0.9487  , -0.758   ,  1.015   ,  0.4985  ,  0.3718  ],
#        [ 1.141   , -0.4587  , -0.674   ,  0.8594  ,  1.219   ],
#        [-0.612   , -1.206   ,  0.698   ,  0.3542  , -0.9346  ],
#        [ 1.006   , -0.1599  , -1.167   , -0.2234  ,  0.12463 ],
#        [ 1.006   , -1.281   , -0.463   ,  1.689   , -1.746   ],
#        [ 1.545   , -0.04788 ,  1.296   , -0.801   ,  0.5835  ],
#        [ 1.106   , -1.58    ,  0.874   , -0.4038  ,  1.254   ],
#        [ 0.3992  ,  0.886   ,  1.261   , -0.11505 , -0.652   ],
#        [-1.286   ,  1.446   , -1.448   ,  0.282   , -0.4753  ],
#        [-0.713   , -1.617   , -0.85    ,  1.329   ,  1.36    ],
#        [-0.8813  ,  0.2883  , -0.005497, -0.006767, -1.075   ],
#        [ 0.1295  , -0.6084  ,  0.5576  , -0.4038  , -0.4048  ]],
#       dtype=float16)

# %%
see_data(dataset)

# %%
dataset.mean(axis=0)

# %%
dataset.std(axis=0)
