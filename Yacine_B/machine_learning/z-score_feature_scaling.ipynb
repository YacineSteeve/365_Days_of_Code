# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
np.random.seed(0)
dataset = np.random.randint(0, 100, [50, 5])

dataset
# Out:
# array([[44, 47, 64, 67, 67],
#        [ 9, 83, 21, 36, 87],
#        [70, 88, 88, 12, 58],
#        [65, 39, 87, 46, 88],
#        [81, 37, 25, 77, 72],
#        [ 9, 20, 80, 69, 79],
#        [47, 64, 82, 99, 88],
#        [49, 29, 19, 19, 14],
#        [39, 32, 65,  9, 57],
#        [32, 31, 74, 23, 35],
#        [75, 55, 28, 34,  0],
#        [ 0, 36, 53,  5, 38],
#        [17, 79,  4, 42, 58],
#        [31,  1, 65, 41, 57],
#        [35, 11, 46, 82, 91],
#        [ 0, 14, 99, 53, 12],
#        [42, 84, 75, 68,  6],
#        [68, 47,  3, 76, 52],
#        [78, 15, 20, 99, 58],
#        [23, 79, 13, 85, 48],
#        [49, 69, 41, 35, 64],
#        [95, 69, 94,  0, 50],
#        [36, 34, 48, 93,  3],
#        [98, 42, 77, 21, 73],
#        [ 0, 10, 43, 58, 23],
#        [59,  2, 98, 62, 35],
#        [94, 67, 82, 46, 99],
#        [20, 81, 50, 27, 14],
#        [41, 58, 65, 36, 10],
#        [86, 43, 11,  2, 51],
#        [80, 32, 54,  0, 38],
#        [19, 46, 42, 56, 60],
# ...

# %%
_, subs = plt.subplots(1, dataset.shape[1])

for p, i in zip(subs, range(dataset.shape[1])):
    p.set_title(f"Col {i+1}")
    p.plot(np.arange(0, dataset.shape[0]), dataset[:, i])

# %%
dataset = dataset.astype(np.float16)

for i in range(dataset.shape[1]):
    m = dataset[:, i].mean()
    std = dataset[:, i].std()
    dataset[:, i] = (dataset[:, i] - m) / std

dataset
# Out:
# array([[-0.1738  ,  0.06415 ,  0.4514  ,  0.751   ,  0.5835  ],
#        [-1.354   ,  1.408   , -1.06    , -0.3674  ,  1.29    ],
#        [ 0.7026  ,  1.595   ,  1.295   , -1.233   ,  0.2659  ],
#        [ 0.534   , -0.2345  ,  1.26    , -0.006763,  1.325   ],
#        [ 1.073   , -0.3093  , -0.9194  ,  1.111   ,  0.7603  ],
#        [-1.354   , -0.944   ,  1.014   ,  0.823   ,  1.007   ],
#        [-0.0727  ,  0.6987  ,  1.084   ,  1.905   ,  1.325   ],
#        [-0.005264, -0.608   , -1.13    , -0.981   , -1.287   ],
#        [-0.3423  , -0.4958  ,  0.4866  , -1.342   ,  0.2306  ],
#        [-0.578   , -0.533   ,  0.8027  , -0.8364  , -0.546   ],
#        [ 0.871   ,  0.3628  , -0.814   , -0.4397  , -1.781   ],
#        [-1.656   , -0.3467  ,  0.0648  , -1.486   , -0.4402  ],
#        [-1.084   ,  1.259   , -1.657   , -0.1511  ,  0.2659  ],
#        [-0.612   , -1.653   ,  0.4866  , -0.1871  ,  0.2306  ],
#        [-0.477   , -1.28    , -0.1813  ,  1.292   ,  1.431   ],
# ...

# %%
_, subs = plt.subplots(1, dataset.shape[1])

for p, i in zip(subs, range(dataset.shape[1])):
    p.set_title(f"Col {i+1}")
    p.plot(np.arange(0, dataset.shape[0]), dataset[:, i])
