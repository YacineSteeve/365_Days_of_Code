# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
image = plt.imread('bacterias.jpg')

# %%
image.shape
# Out:
# (405, 600, 3)

# %%
plt.imshow(image)

# %%
img = np.copy(image[:, :, 0])
plt.figure(figsize=(12, 5))
plt.hist(img.ravel(), bins=255)
# Out:
# (array([1.5500e+02, 3.2000e+01, 3.3000e+01, 4.7000e+01, 4.4000e+01,
#         6.0000e+01, 7.2000e+01, 6.3000e+01, 6.9000e+01, 7.8000e+01,
#         8.8000e+01, 8.1000e+01, 8.8000e+01, 8.4000e+01, 1.0900e+02,
#         1.0600e+02, 9.6000e+01, 1.1000e+02, 1.0700e+02, 1.3300e+02,
#         1.5900e+02, 1.1300e+02, 1.9900e+02, 1.8200e+02, 1.9400e+02,
#         1.8700e+02, 2.2500e+02, 2.6100e+02, 2.1400e+02, 2.4900e+02,
#         2.6600e+02, 2.7900e+02, 3.0200e+02, 3.0800e+02, 3.4600e+02,
#         3.2800e+02, 3.7900e+02, 3.8500e+02, 4.1100e+02, 4.6300e+02,
#         4.5400e+02, 4.3400e+02, 4.5500e+02, 4.8800e+02, 5.0700e+02,
#         5.3800e+02, 5.2100e+02, 5.8100e+02, 5.9200e+02, 5.7200e+02,
#         5.7500e+02, 6.0900e+02, 5.6500e+02, 5.9100e+02, 6.4600e+02,
#         5.8800e+02, 5.8800e+02, 5.9400e+02, 6.4400e+02, 6.0700e+02,
#         6.4900e+02, 6.4900e+02, 6.4900e+02, 6.8900e+02, 6.0800e+02,
#         6.4400e+02, 6.6100e+02, 6.3000e+02, 7.1300e+02, 6.6600e+02,
# ...

# %%
image = image[image >= 150]
image.shape
# Out:
# (527213,)
